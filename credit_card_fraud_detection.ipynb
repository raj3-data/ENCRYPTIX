# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\rajar\OneDrive\Desktop\credit card fraud\creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns=None

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
print(f"no of coloumns is : {data.shape[1]}")
# Out:
# no of coloumns is : 31

# %%
print(f"no of rows is : {data.shape[0]}")
# Out:
# no of rows is : 284807

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#normal approach
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
data['Amount']= sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data= data.drop(['Time'],axis=1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
#checking for duplicate value
data.duplicated().any()
# Out:
# np.True_

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
#checking if balance or imbalance data set
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
# !pip install seaborn
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
#x-->ind var,y-->dep var
x=data.drop('Class',axis=1)
y=data['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y , test_size=0.2,random_state=42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score,recall_score

# %%
classifier={
    "Logistic Regression":LogisticRegression(),
    "Decession tree classifier" :DecisionTreeClassifier()
}
for name,clf in classifier.items():
    print(f"\n========{name}=========")
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    print(f"\n accuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\n precession: {precision_score(y_test,y_pred)}")
    print(f"\n recall: {recall_score(y_test,y_pred)}")
    print(f"\n f1 score: {f1_score(y_test,y_pred)}")
# Out:
# ========Logistic Regression=========
#
#  accuracy: 0.9992563437505668
#
#  precession: 0.890625
#
#  recall: 0.6263736263736264
#
#  f1 score: 0.7354838709677419
#
# ========Decession tree classifier=========
#
#  accuracy: 0.9988754466471986
#
#  precession: 0.6494845360824743
#
#  recall: 0.6923076923076923
#
#  f1 score: 0.6702127659574468

# %%
#handling data imbalance
#under sampling-->make data based on minority class
#many data is lost
normal=data[data['Class']==0]
fraud=data[data['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normmal_sample=normal.sample(n=473)

# %%
normmal_sample.shape
# Out:
# (473, 30)

# %%
new_data=pd.concat([normmal_sample,fraud],ignore_index=True)

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.198079  0.211615  0.383961  0.638333 -0.533032 -0.896752 -0.103236
# 1 -1.082850  2.139390 -1.656912 -0.071538  0.053403 -0.871702 -0.184955
# 2 -3.164422 -3.327916  2.126832  3.599307  4.056213 -1.843085 -1.993807
# 3 -0.043779  0.910071 -0.001841  0.083384  0.869331 -0.612157  0.787256
# 4 -0.217248  0.522971  1.575324 -1.007661 -0.039535 -1.501461  0.853140
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.006771 -0.037185 -0.074551  1.584634  0.274390 -1.241209  0.189318
# 1  0.990570  0.557785 -1.501921  1.620023 -1.288264  2.540374  1.392274
# 2  0.240025  0.629233  0.590762  1.273693 -1.789273  1.782897  1.328411
# 3 -0.043803 -0.263333 -0.788419 -0.817591 -1.026761 -1.454905 -0.537612
# 4 -0.725267 -0.573967  0.012390  1.292623 -2.792166  2.656364  1.070471
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
##x-->ind var,y-->dep var
x=new_data.drop('Class',axis=1)
y=new_data['Class']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y , test_size=0.2,random_state=42)

# %%
classifier={
    "Logistic Regression":LogisticRegression(),
    "Decession tree classifier" :DecisionTreeClassifier()
}
for name,clf in classifier.items():
    print(f"\n========{name}=========")
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    print(f"\n accuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\n precession: {precision_score(y_test,y_pred)}")
    print(f"\n recall: {recall_score(y_test,y_pred)}")
    print(f"\n f1 score: {f1_score(y_test,y_pred)}")
# Out:
# ========Logistic Regression=========
#
#  accuracy: 0.9105263157894737
#
#  precession: 0.9207920792079208
#
#  recall: 0.9117647058823529
#
#  f1 score: 0.916256157635468
#
# ========Decession tree classifier=========
#
#  accuracy: 0.8894736842105263
#
#  precession: 0.8932038834951457
#
#  recall: 0.9019607843137255
#
#  f1 score: 0.8975609756097561

# %%
#handling imbalanace data (2)
#oversampling-->data based on majority class
#x-->ind var,y-->dep var
x=data.drop('Class',axis=1)
y=data['Class']

# %%
# !pip install imbalanced-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

# %%
x_res,y_res=SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res , test_size=0.2,random_state=42)

# %%
classifier={
    "Logistic Regression":LogisticRegression(),
    "Decession tree classifier" :DecisionTreeClassifier()
}
for name,clf in classifier.items():
    print(f"\n========{name}=========")
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    print(f"\n accuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\n precession: {precision_score(y_test,y_pred)}")
    print(f"\n recall: {recall_score(y_test,y_pred)}")
    print(f"\n f1 score: {f1_score(y_test,y_pred)}")
# Out:
# ========Logistic Regression=========
#
#  accuracy: 0.9444747265525637
#
#  precession: 0.9728610944542236
#
#  recall: 0.9143864880097449
#
#  f1 score: 0.942717900656045
#
# ========Decession tree classifier=========
#
#  accuracy: 0.9980195501290018
#
#  precession: 0.9971325384294296
#
#  recall: 0.9989091504099776
#
#  f1 score: 0.9980200537673473

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
# !pip install joblib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import joblib

# %%
joblib.dump(dtc,"credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
model=joblib.load("credit_card_model.pkl")

# %%
pred=model.predict([[1.19185711131486,0.26615071205963,0.16648011335321,0.448154078460911,0.0600176492822243,-0.0823608088155687,-0.0788029833323113,0.0851016549148104,-0.255425128109186,-0.166974414004614,1.61272666105479,1.06523531137287,0.48909501589608,-0.143772296441519,0.635558093258208,0.463917041022171,-0.114804663102346,-0.183361270123994,-0.145783041325259,-0.0690831352230203,-0.225775248033138,-0.638671952771851,0.101288021253234,-0.339846475529127,0.167170404418143,0.125894532368176,-0.00898309914322813,0.0147241691924927,2.69]])
# Out:
# C:\Users\rajar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pred[0]
# Out:
# np.int64(0)

# %%
if pred==0:
    print("normal transaction")
else:
    print("fraud transaction")
# Out:
# normal transaction
